# %%
import tweepy
import csv
import pandas as pd

access_token="1404055829125337090-rHLSB8Gn3EzPI3Vsb6xLDZfNSVrYWf"
access_token_secret="Jz7Dkqs5wN3JKnZXOEd5hlkNIl1Q6PLOj7ruQQQwxCwdj"
api_key="9az1pkSeWJ96sDaMw15bCqo5O"
api_key_secret="n8wdw9UYicMeTxJgShiLe5Qkw4HVvFxUJQw1H52U3a011dLjuQ"

auth=tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
search_key="data analyst"

csvfile= open(search_key+".csv","a+",newline="",encoding="utf-8")
csvwriter=csv.writer(csvfile)
c = []
i =[]
u = []
t = []
for tweet in tweepy.Cursor(api.search,q=search_key,count=2000, lang='id').items():
    print(tweet.created_at,tweet.id,tweet.user.name,tweet.text)
    c.append(tweet.created_at)
    i.append(tweet.id)
    u.append(tweet.user.name)
    t.append(tweet.text.encode("utf-8"))
    tweets= [tweet.created_at,tweet.id,tweet.user.name,tweet.text.encode("utf-8")]
    csvwriter.writerow(tweets)
    
dicttweets={"waktu":c,"id":i,"username":u, "teks":t}
df= pd.DataFrame(dicttweets, columns=["waktu","id","username","teks"])
df.to_csv(r'C:\Users\win10\Downloads\DA\data_analyst.csv',header='column_names')
# Out:
# 2022-07-16 08:41:53 1548226401404583936 cha Hmmmmmm, x suka coding tp kenapala syelalu end up dgn coding. Cita cita aku nk jadi data analyst ja bukan programme… https://t.co/vYTHJalbI5
# 2022-07-16 07:45:35 1548212232865329153 radityari @txtfrombrand Di tangan fakhira mah sudah terblokir lapaknya @Fakhirayasminz
# Bismillah data analyst shopee🙏🏽
# 2022-07-16 07:42:39 1548211493745074178 nattokki @nonntft @collegemenfess Ga sekedar perkenalan aja kok. Di jelasin gambaran besarnya dari data analyst itu apa, sam… https://t.co/Xc24HhLy5t
# 2022-07-16 06:23:19 1548191532372881413 Henry S 🐝 @Darrod_ @legolard Ada 1 jurnalis Tifo udah jadi data analyst di RB Leipzig. Scattergram guy.
# 2022-07-16 04:49:40 1548167961579769856 COLLE [cm] kalian yg sekarang menekuni data analyst belajar awalnya darimana ? aku tertarik tp blm ada basicnya samsek
# ...

# %%
import tweepy
import csv
import pandas as pd

access_token="1404055829125337090-rHLSB8Gn3EzPI3Vsb6xLDZfNSVrYWf"
access_token_secret="Jz7Dkqs5wN3JKnZXOEd5hlkNIl1Q6PLOj7ruQQQwxCwdj"
api_key="9az1pkSeWJ96sDaMw15bCqo5O"
api_key_secret="n8wdw9UYicMeTxJgShiLe5Qkw4HVvFxUJQw1H52U3a011dLjuQ"

auth=tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
search_key="data scientist"

csvfile= open(search_key+".csv","a+",newline="",encoding="utf-8")
csvwriter=csv.writer(csvfile)
c = []
i =[]
u = []
t = []
for tweet in tweepy.Cursor(api.search,q=search_key,count=2000, lang='id').items():
    print(tweet.created_at,tweet.id,tweet.user.name,tweet.text)
    c.append(tweet.created_at)
    i.append(tweet.id)
    u.append(tweet.user.name)
    t.append(tweet.text.encode("utf-8"))
    tweets= [tweet.created_at,tweet.id,tweet.user.name,tweet.text.encode("utf-8")]
    csvwriter.writerow(tweets)
    
dicttweets={"waktu":c,"id":i,"username":u, "teks":t}
df= pd.DataFrame(dicttweets, columns=["waktu","id","username","teks"])
df.to_csv(r'C:\Users\win10\Downloads\DA\data_scientist.csv',header='column_names')
# Out:
# 2022-07-16 04:39:19 1548165356002238466 IkoKaziKe_Bot RT @DataNomadKE: Data Scientist| @KCBGroup|Kenya
# #IkoKaziKE
# https://t.co/hhyYg5vFib
# 2022-07-16 03:09:32 1548142761928364034 han ❤️‍🔥 MINGI @worksfess Ikut pelatihan nder, sayang bangettt ilmu di mtk nya pasti cocok jd data analyst/scientist
# 2022-07-16 02:43:52 1548136303572963328 han @collegemenfess Banyak nder, kalo mau belajar lagi mah bisa ke data analyst/scientist.
# 2022-07-16 01:03:29 1548111042172964865 Kazybot RT @DataNomadKE: Data Scientist| @KCBGroup|Kenya
# #IkoKaziKE
# https://t.co/hhyYg5vFib
# 2022-07-15 23:37:44 1548089460826353665 Statistika UII @schfess Prospek kerja lulusan statistika jadi apa aja sih?🤔
# 1. Data Scientist
# Lulusan statistika bisa bekerja seba… https://t.co/iUASeO9Wxk
# 2022-07-15 15:06:33 1547960817005367301 Bryson Mwamburi RT @DataNomadKE: Data Scientist| @KCBGroup|Kenya
# #IkoKaziKE
# https://t.co/hhyYg5vFib
# ...

# %%
import tweepy
import csv
import pandas as pd

access_token="1404055829125337090-rHLSB8Gn3EzPI3Vsb6xLDZfNSVrYWf"
access_token_secret="Jz7Dkqs5wN3JKnZXOEd5hlkNIl1Q6PLOj7ruQQQwxCwdj"
api_key="9az1pkSeWJ96sDaMw15bCqo5O"
api_key_secret="n8wdw9UYicMeTxJgShiLe5Qkw4HVvFxUJQw1H52U3a011dLjuQ"

auth=tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
search_key="data engineer"

csvfile= open(search_key+".csv","a+",newline="",encoding="utf-8")
csvwriter=csv.writer(csvfile)
c = []
i =[]
u = []
t = []
for tweet in tweepy.Cursor(api.search,q=search_key,count=2000, lang='id').items():
    print(tweet.created_at,tweet.id,tweet.user.name,tweet.text)
    c.append(tweet.created_at)
    i.append(tweet.id)
    u.append(tweet.user.name)
    t.append(tweet.text.encode("utf-8"))
    tweets= [tweet.created_at,tweet.id,tweet.user.name,tweet.text.encode("utf-8")]
    csvwriter.writerow(tweets)
    
dicttweets={"waktu":c,"id":i,"username":u, "teks":t}
df= pd.DataFrame(dicttweets, columns=["waktu","id","username","teks"])
df.to_csv(r'C:\Users\win10\Downloads\DA\data_engineer.csv',header='column_names')
# Out:
# 2022-07-16 11:41:04 1548271495163842560 PututPranoto RT @budimandjatmiko: Pagi ini putriku (sbg cloud engineer) &amp; tim-nya (programmer &amp; data supporter) sedang presentasi problem diagnosa stunt…
# 2022-07-16 11:33:40 1548269631097667585 Youfree Yus RT @budimandjatmiko: Pagi ini putriku (sbg cloud engineer) &amp; tim-nya (programmer &amp; data supporter) sedang presentasi problem diagnosa stunt…
# 2022-07-16 11:27:20 1548268039153815552 Joe RT @budimandjatmiko: Pagi ini putriku (sbg cloud engineer) &amp; tim-nya (programmer &amp; data supporter) sedang presentasi problem diagnosa stunt…
# 2022-07-16 11:20:59 1548266441480507392 Beno RT @budimandjatmiko: Pagi ini putriku (sbg cloud engineer) &amp; tim-nya (programmer &amp; data supporter) sedang presentasi problem diagnosa stunt…
# 2022-07-16 11:09:31 1548263555199561729 St. Budi RT @budimandjatmiko: Pagi ini putriku (sbg cloud engineer) &amp; tim-nya (programmer &amp; data supporter) sedang presentasi problem diagnosa stunt…
# ...

# %%
df=pd.read_csv(r'C:\Users\win10\Downloads\DA\data_engineer.csv')

# %%
d
